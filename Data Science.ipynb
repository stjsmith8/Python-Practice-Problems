# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Stephanie Smith**
# Data Analyst

# %% [markdown]
# _I am interested in Data Science because I want to learn new skills and furter my career._

# %% [markdown]
# ### This code shows an arithmetic expression

# %%
((4*4)+(6/2)-(5*20))+((34*5)+(16/4))
# Out:
# 93.0

# %% [markdown]
# A place I have visited recently:
# Seville, Spain ![Seville Picture](https://www.tripsavvy.com/thmb/ajUlqdOQd8muypK86Cbt7VtXVrM=/750x0/filters:no_upscale():max_bytes(150000):strip_icc()/DSC_0128-206cdc2eedc34f719a7b328e3bf1c6e6.jpg)
#
#
# [Best Things to Do in Seville, Spain](https://www.tripsavvy.com/things-to-do-in-seville-1644161)
#
# Favorite Tapas from Seville:
# 1. Croquettes
# 2. Albondigas
# 3. Papas bravas
# 4. Salmorejo
